# %% [markdown]
# # Checking the Data Memory Footprint
# This is so we have a idea of the total size of the filtered mesh data. It will also help with the selection of further analysis tools.

# %%
# !du -sh ../data/*.parquet | sort -h
# Out:
# 311M	../data/prime_location_data.parquet
# 335M	../data/citation_counts_data.parquet
# 345M	../data/topic_data.parquet
# 1006M	../data/authors_data.parquet
# 2.1G	../data/related_data.parquet
# 3.6G	../data/keyword_data.parquet
# 4.8G	../data/cited_data.parquet
# 7.5G	../data/work.parquet

# %% [markdown]
# # Check all the file shapes and the schemas

# %%
import polars as pl
import pyarrow.parquet as pq
from pathlib import Path

data_dir = Path("../data")

files = [
    "work.parquet",
    "cited_data.parquet",
    "keyword_data.parquet",
    "related_data.parquet",
    "authors_data.parquet",
    "topic_data.parquet",
    "citation_counts_data.parquet", 
    "prime_location_data.parquet",
]

for fname in files:
    path = data_dir / fname
    
    # Schema only — no data loaded
    schema = pl.scan_parquet(path).collect_schema()
    
    # Row count from metadata — no data loaded
    num_rows = pq.read_metadata(path).num_rows
    num_cols = len(schema)
    
    print(f"\n{'='*50}")
    print(f"FILE: {fname}")
    print(f"Shape: {num_rows:,} rows x {num_cols} cols")
    print(f"{'─'*50}")
    for col_name, dtype in schema.items():
        print(f"  {col_name:<35} {dtype}")
# Out:
# ==================================================
# FILE: work.parquet
# Shape: 32,685,742 rows x 18 cols
# ──────────────────────────────────────────────────
#   paper_id                            String
#   paper_title                         String
#   publication_date                    Date
#   type                                String
#   authors_count                       Int64
#   language                            String
#   locations_count                     Int64
#   countries_distinct_count            Int64
#   institutions_distinct_count         Int64
#   referenced_works_count              Int64
#   cited_by_count                      Int64
#   fwci_val                            Float32
#   updated_date                        Date
#   is_oa                               Boolean
#   oa_status                           String
#   percentile_rank                     Float32
#   cited_by_percentile_year_avg        Float32
#   abstract                            String
#
# ==================================================
# FILE: cited_data.parquet
# Shape: 863,832,854 rows x 2 cols
# ──────────────────────────────────────────────────
#   paper_id                            String
#   cited_id                            String
#
# ==================================================
# FILE: keyword_data.parquet
# Shape: 353,155,700 rows x 3 cols
# ──────────────────────────────────────────────────
#   paper_id                            String
#   keyword_id                          String
#   score                               Float64
#
# ==================================================
# FILE: related_data.parquet
# Shape: 325,826,457 rows x 2 cols
# ──────────────────────────────────────────────────
#   paper_id                            String
#   related_id                          String
#
# ==================================================
# FILE: authors_data.parquet
# Shape: 147,848,907 rows x 2 cols
# ──────────────────────────────────────────────────
#   paper_id                            String
#   author_id                           String
#
# ==================================================
# FILE: topic_data.parquet
# Shape: 86,757,659 rows x 2 cols
# ──────────────────────────────────────────────────
#   paper_id                            String
#   topic_id                            String
#
# ==================================================
# FILE: citation_counts_data.parquet
# Shape: 150,401,551 rows x 3 cols
# ──────────────────────────────────────────────────
#   paper_id                            String
#   citation_year                       Int64
#   yearly_citations                    Int64
#
# ==================================================
# FILE: prime_location_data.parquet
# Shape: 32,626,333 rows x 5 cols
# ──────────────────────────────────────────────────
#   paper_id                            String
#   source_id                           String
#   source_name                         String
#   host_org_id                         String
#   host_org_name                       String

# %%
# import polars as pl
# from pathlib import Path

# data_dir = Path("../data")

# files = [
#     "work.parquet",
#     "cited_data.parquet",
#     "keyword_data.parquet",
#     "related_data.parquet",
#     "authors_data.parquet",
#     "topic_data.parquet",
#     "citation_counts_data.parquet", 
#     "prime_location_data.parquet",
# ]

# for fname in files:
#     path = data_dir / fname
    
#     total_rows = pq.read_metadata(path).num_rows
    
#     # Count unique rows — lazy until collect
#     unique_rows = (
#         pl.scan_parquet(path)
#         .unique()
#         .collect()
#         .height
#     )
    
#     duplicates = total_rows - unique_rows
    
#     print(f"{fname:<40} total: {total_rows:>10,} | unique: {unique_rows:>10,} | duplicates: {duplicates:>8,}")
